# %% [markdown]
# # Intro of this file
# + Heads: segmentation only
# + Performs 5 fold cv on (main args might want to change: batchsize=8, fold=5, ep=10)
# + To change the fold numbers, simply change "CVfolds" in the section "Start cross validation"
# + loader and train is modified compared to the main branch

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
import numpy as np
import random
import matplotlib.pyplot as plt

from utils.loader import DataLoader
from models.effnet_encoder import EffnetEncoder
from models.mtl_framework import MTLFramework
from utils import tools, config

# %%
# Set configs
batch_size = 8
batch_size_val = 8
num_train, num_val, num_test = config.config['num_train'], config.config['num_val'], config.config['num_test']
img_height, img_width, channels = config.config['input_shape']

# %% [markdown]
# ### Build our MTL

# %%
def build_model(img_height, img_width, channels):
    ### CLEARS OLD MODELS IN CACHE
    tf.keras.backend.clear_session()

    # Get encoder
    base_model_name = 'B0'
    encoder = EffnetEncoder(base_model_name, (img_height, img_width, channels)).build_encoder(trainable=True)

    # Use our MTL framework to custom build a model
    mtl_builder = MTLFramework(encoder, (img_height, img_width, channels))
    mtl_builder.add_segmentation_head()
    # mtl_builder.add_binary_classification_head(base_model_name, trainable=True)
    # mtl_builder.add_bbox_classification_head(base_model_name, trainable=True)
    model = mtl_builder.build_mtl_model()

    return model

# %% [markdown]
# ### Train model

# %%
def generator_img(img_ds, masks_ds):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds.as_numpy_iterator()
    b = masks_ds.as_numpy_iterator()
    # c = label_ds.as_numpy_iterator()
    # d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        # Y2 = c.next()
        # Y3 = d.next()
        
        # Regularisation and shuffling
        X, Y1 = tools.get_randomised_data([X, Y1])
        # X, Y1, Y3 = tools.data_augmentation(X, Y1, Y3) # Fix augmentation
        
        yield X, (Y1)

# %%
def generator_img_val(img_ds_val, masks_ds_val):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds_val.as_numpy_iterator()
    b = masks_ds_val.as_numpy_iterator()
    # c = label_ds_val.as_numpy_iterator()
    # d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        # Y2 = c.next()
        # Y3 = d.next()
        
        yield X, (Y1)

# %% [markdown]
# ### Start cross validation

# %%
##### Change this to modify the folds #####
CVfolds = 5
ep = 10
###########################################
cv_history = []
num_train_cv = num_train * (CVfolds-1)/CVfolds
num_val_cv = num_train * 1/CVfolds

for cv_iter in range(CVfolds):
      # CrossVal: 0 = no CV, 1 = training set, 2 = val set
      loader1 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=1, CV_iteration=cv_iter, fold=CVfolds)
      loader2 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=2, CV_iteration=cv_iter, fold=CVfolds)

      # Train set
      img_ds = loader1.get_image_ds().repeat()
      masks_ds = loader1.get_mask_ds().repeat()
      label_ds = loader1.get_binary_ds().repeat()
      bbox_ds = loader1.get_bboxes_ds().repeat()

      # Validation set
      img_ds_val = loader2.get_image_ds().repeat()
      masks_ds_val = loader2.get_mask_ds().repeat()
      label_ds_val = loader2.get_binary_ds().repeat()
      bbox_ds_val = loader2.get_bboxes_ds().repeat()
      
      model = build_model(img_height, img_width, channels)

      model.compile(optimizer=keras.optimizers.Adam(1e-4),
                  loss={'segnet_out' : tf.keras.losses.BinaryCrossentropy(from_logits=True)},
                  loss_weights=[1], # Scale MAE to BC range
                  metrics=['accuracy'])

      print(f"-------------------- start cross val {cv_iter+1}/{CVfolds} --------------------")

      history = model.fit(generator_img(img_ds, masks_ds), 
                        validation_data=generator_img_val(img_ds_val, masks_ds_val), 
                        epochs=ep, 
                        steps_per_epoch=num_train_cv//batch_size, 
                        validation_steps=num_val_cv//batch_size_val)

      # save the final val_acc of each cv step
      cv_history.append(history.history)
# Out:
# -------------------- start cross val 1/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 83s 333ms/step - loss: 0.4294 - accuracy: 0.7984 - val_loss: 0.2268 - val_accuracy: 0.9304
# Epoch 2/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.2038 - accuracy: 0.9325 - val_loss: 0.1624 - val_accuracy: 0.9470
# Epoch 3/10
# 221/221 [==============================] - 75s 340ms/step - loss: 0.1485 - accuracy: 0.9535 - val_loss: 0.1403 - val_accuracy: 0.9514
# Epoch 4/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.1228 - accuracy: 0.9602 - val_loss: 0.1350 - val_accuracy: 0.9505
# Epoch 5/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.1075 - accuracy: 0.9641 - val_loss: 0.1280 - val_accuracy: 0.9523
# Epoch 6/10
# 221/221 [==============================] - 74s 334ms/step - loss: 0.0961 - accuracy: 0.9676 - val_loss: 0.1233 - val_accuracy: 0.9546
# Epoch 7/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.0881 - accuracy: 0.9699 - val_loss: 0.1227 - val_accuracy: 0.9555
# Epoch 8/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.0822 - accuracy: 0.9716 - val_loss: 0.1247 - val_accuracy: 0.9544
# Epoch 9/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.0773 - accuracy: 0.9733 - val_loss: 0.1219 - val_accuracy: 0.9563
# Epoch 10/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.0721 - accuracy: 0.9751 - val_loss: 0.1242 - val_accuracy: 0.9558
# -------------------- start cross val 2/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 82s 345ms/step - loss: 0.4482 - accuracy: 0.7837 - val_loss: 0.2208 - val_accuracy: 0.9402
# Epoch 2/10
# 221/221 [==============================] - 75s 338ms/step - loss: 0.2040 - accuracy: 0.9366 - val_loss: 0.1631 - val_accuracy: 0.9459
# Epoch 3/10
# 221/221 [==============================] - 74s 334ms/step - loss: 0.1473 - accuracy: 0.9539 - val_loss: 0.1328 - val_accuracy: 0.9552
# Epoch 4/10
# 221/221 [==============================] - 73s 329ms/step - loss: 0.1220 - accuracy: 0.9602 - val_loss: 0.1219 - val_accuracy: 0.9566
# Epoch 5/10
# 221/221 [==============================] - 73s 329ms/step - loss: 0.1058 - accuracy: 0.9646 - val_loss: 0.1191 - val_accuracy: 0.9562
# Epoch 6/10
# 221/221 [==============================] - 73s 332ms/step - loss: 0.0952 - accuracy: 0.9676 - val_loss: 0.1178 - val_accuracy: 0.9563
# Epoch 7/10
# 221/221 [==============================] - 73s 333ms/step - loss: 0.0873 - accuracy: 0.9700 - val_loss: 0.1149 - val_accuracy: 0.9572
# Epoch 8/10
# 221/221 [==============================] - 74s 334ms/step - loss: 0.0804 - accuracy: 0.9722 - val_loss: 0.1128 - val_accuracy: 0.9589
# Epoch 9/10
# 221/221 [==============================] - 73s 333ms/step - loss: 0.0760 - accuracy: 0.9735 - val_loss: 0.1142 - val_accuracy: 0.9580
# Epoch 10/10
# 221/221 [==============================] - 73s 330ms/step - loss: 0.0722 - accuracy: 0.9749 - val_loss: 0.1130 - val_accuracy: 0.9594
# -------------------- start cross val 3/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 82s 345ms/step - loss: 0.4994 - accuracy: 0.7822 - val_loss: 0.2453 - val_accuracy: 0.9313
# Epoch 2/10
# 221/221 [==============================] - 75s 338ms/step - loss: 0.2112 - accuracy: 0.9345 - val_loss: 0.1746 - val_accuracy: 0.9437
# Epoch 3/10
# 221/221 [==============================] - 79s 357ms/step - loss: 0.1507 - accuracy: 0.9540 - val_loss: 0.1472 - val_accuracy: 0.9508
# Epoch 4/10
# 221/221 [==============================] - 81s 370ms/step - loss: 0.1224 - accuracy: 0.9610 - val_loss: 0.1392 - val_accuracy: 0.9516
# Epoch 5/10
# 221/221 [==============================] - 84s 383ms/step - loss: 0.1065 - accuracy: 0.9651 - val_loss: 0.1322 - val_accuracy: 0.9534
# Epoch 6/10
# 221/221 [==============================] - 88s 399ms/step - loss: 0.0954 - accuracy: 0.9679 - val_loss: 0.1312 - val_accuracy: 0.9522
# Epoch 7/10
# 221/221 [==============================] - 86s 391ms/step - loss: 0.0871 - accuracy: 0.9704 - val_loss: 0.1297 - val_accuracy: 0.9530
# Epoch 8/10
# 221/221 [==============================] - 94s 427ms/step - loss: 0.0803 - accuracy: 0.9726 - val_loss: 0.1288 - val_accuracy: 0.9536
# Epoch 9/10
# 221/221 [==============================] - 76s 346ms/step - loss: 0.0756 - accuracy: 0.9740 - val_loss: 0.1313 - val_accuracy: 0.9531
# Epoch 10/10
# 221/221 [==============================] - 91s 412ms/step - loss: 0.0714 - accuracy: 0.9754 - val_loss: 0.1332 - val_accuracy: 0.9531
# -------------------- start cross val 4/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 81s 342ms/step - loss: 0.4413 - accuracy: 0.7929 - val_loss: 0.2287 - val_accuracy: 0.9374
# Epoch 2/10
# 221/221 [==============================] - 105s 478ms/step - loss: 0.2041 - accuracy: 0.9361 - val_loss: 0.1595 - val_accuracy: 0.9510
# Epoch 3/10
# 221/221 [==============================] - 83s 379ms/step - loss: 0.1474 - accuracy: 0.9541 - val_loss: 0.1376 - val_accuracy: 0.9537
# Epoch 4/10
# 221/221 [==============================] - 77s 351ms/step - loss: 0.1216 - accuracy: 0.9606 - val_loss: 0.1289 - val_accuracy: 0.9551
# Epoch 5/10
# 221/221 [==============================] - 92s 417ms/step - loss: 0.1055 - accuracy: 0.9648 - val_loss: 0.1224 - val_accuracy: 0.9567
# Epoch 6/10
# 221/221 [==============================] - 88s 399ms/step - loss: 0.0956 - accuracy: 0.9676 - val_loss: 0.1231 - val_accuracy: 0.9548
# Epoch 7/10
# 221/221 [==============================] - 147s 668ms/step - loss: 0.0869 - accuracy: 0.9702 - val_loss: 0.1184 - val_accuracy: 0.9574
# Epoch 8/10
# 221/221 [==============================] - 128s 580ms/step - loss: 0.0805 - accuracy: 0.9723 - val_loss: 0.1195 - val_accuracy: 0.9571
# Epoch 9/10
# 221/221 [==============================] - 740s 3s/step - loss: 0.0748 - accuracy: 0.9743 - val_loss: 0.1179 - val_accuracy: 0.9585
# Epoch 10/10
# 221/221 [==============================] - 83s 376ms/step - loss: 0.0714 - accuracy: 0.9753 - val_loss: 0.1190 - val_accuracy: 0.9583
# -------------------- start cross val 5/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 87s 367ms/step - loss: 0.4083 - accuracy: 0.8125 - val_loss: 0.2152 - val_accuracy: 0.9363
# Epoch 2/10
# 221/221 [==============================] - 81s 367ms/step - loss: 0.1939 - accuracy: 0.9384 - val_loss: 0.1596 - val_accuracy: 0.9463
# Epoch 3/10
# 221/221 [==============================] - 80s 365ms/step - loss: 0.1419 - accuracy: 0.9547 - val_loss: 0.1406 - val_accuracy: 0.9498
# Epoch 4/10
# 221/221 [==============================] - 80s 365ms/step - loss: 0.1174 - accuracy: 0.9612 - val_loss: 0.1320 - val_accuracy: 0.9521
# Epoch 5/10
# 221/221 [==============================] - 152s 690ms/step - loss: 0.1028 - accuracy: 0.9651 - val_loss: 0.1303 - val_accuracy: 0.9520
# Epoch 6/10
# 221/221 [==============================] - 107s 486ms/step - loss: 0.0925 - accuracy: 0.9682 - val_loss: 0.1265 - val_accuracy: 0.9539
# Epoch 7/10
# 221/221 [==============================] - 80s 364ms/step - loss: 0.0867 - accuracy: 0.9697 - val_loss: 0.1269 - val_accuracy: 0.9539
# Epoch 8/10
# 221/221 [==============================] - 80s 361ms/step - loss: 0.0803 - accuracy: 0.9719 - val_loss: 0.1288 - val_accuracy: 0.9532
# Epoch 9/10
# 221/221 [==============================] - 81s 367ms/step - loss: 0.0745 - accuracy: 0.9740 - val_loss: 0.1267 - val_accuracy: 0.9549
# Epoch 10/10
# 221/221 [==============================] - 80s 361ms/step - loss: 0.0704 - accuracy: 0.9754 - val_loss: 0.1307 - val_accuracy: 0.9544

# %%
# extract the wanted metrics
result = []
for i in range(CVfolds):
    result.append([cv_history[i]['accuracy'],
                    cv_history[i]['val_accuracy']])

# %%
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(CVfolds):
    ax.plot(result[i][0], linestyle=":", label = f"segment acc, cv {i}")
for i in range(CVfolds):
    ax.plot(result[i][1], linestyle="-", label = f"val segment acc, cv {i}")
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('MTL with segmentation only')
plt.legend()
plt.ylim([0.75, 1])
plt.grid()
plt.show()

# %%
# Print out the results to see offline
print("set \tsegmen ")
for i in range(CVfolds):
    print(f"CV {i+1} \t{np.round(result[i][1][-1], 4)}")

print("-----------------------------")
avg = np.round(np.mean(result, axis=0), 4)
std = np.round(np.std(result, axis=0), 4)
print(f"Avg  \t{avg[1][-1]} ")
print(f"Std  \t{std[1][-1]} ")
# Out:
# set 	segmen
# CV 1 	0.9558
# CV 2 	0.9594
# CV 3 	0.9531
# CV 4 	0.9583
# CV 5 	0.9544
# -----------------------------
# Avg  	0.9562
# Std  	0.0024
