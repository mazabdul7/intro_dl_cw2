# %% [markdown]
# # Intro of this file
# + Heads: segmentation + bbox
# + Performs 5 fold cv (main args might want to change: batchsize=8, fold=5, ep=10)
# + To change the fold numbers, simply change "CVfolds" in the section "Start cross validation"
# + loader and train is modified compared to the main branch

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
import numpy as np
import random
import matplotlib.pyplot as plt

from utils.loader import DataLoader
from models.effnet_encoder import EffnetEncoder
from models.mtl_framework import MTLFramework
from utils import tools, config

# %%
# Set configs
batch_size = 8
batch_size_val = 8
num_train, num_val, num_test = config.config['num_train'], config.config['num_val'], config.config['num_test']
img_height, img_width, channels = config.config['input_shape']

# %% [markdown]
# ### Build our MTL

# %%
def build_model(img_height, img_width, channels):
    ### CLEARS OLD MODELS IN CACHE
    tf.keras.backend.clear_session()

    # Get encoder
    base_model_name = 'B0'
    encoder = EffnetEncoder(base_model_name, (img_height, img_width, channels)).build_encoder(trainable=True)

    # Use our MTL framework to custom build a model
    mtl_builder = MTLFramework(encoder, (img_height, img_width, channels))
    mtl_builder.add_segmentation_head()
    # mtl_builder.add_binary_classification_head(base_model_name, trainable=True)
    mtl_builder.add_bbox_classification_head(base_model_name, trainable=True)
    model = mtl_builder.build_mtl_model()

    return model

# %% [markdown]
# ### Train model

# %%
def generator_img(img_ds, masks_ds, bbox_ds):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds.as_numpy_iterator()
    b = masks_ds.as_numpy_iterator()
    # c = label_ds.as_numpy_iterator()
    d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        # Y2 = c.next()
        Y3 = d.next()
        
        # Regularisation and shuffling
        X, Y1, Y3 = tools.get_randomised_data([X, Y1, Y3])
        # X, Y1, Y3 = tools.data_augmentation(X, Y1, Y3) # Fix augmentation
        
        yield X, (Y1, Y3)

# %%
def generator_img_val(img_ds_val, masks_ds_val, bbox_ds):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds_val.as_numpy_iterator()
    b = masks_ds_val.as_numpy_iterator()
    # c = label_ds_val.as_numpy_iterator()
    d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        # Y2 = c.next()
        Y3 = d.next()
        
        yield X, (Y1, Y3)

# %% [markdown]
# ### Start cross validation

# %%
##### Change this to modify the folds #####
CVfolds = 5
ep = 10
###########################################
cv_history = []
num_train_cv = num_train * (CVfolds-1)/CVfolds
num_val_cv = num_train * 1/CVfolds

for cv_iter in range(CVfolds):
      # CrossVal: 0 = no CV, 1 = training set, 2 = val set
      loader1 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=1, CV_iteration=cv_iter, fold=CVfolds)
      loader2 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=2, CV_iteration=cv_iter, fold=CVfolds)

      # Train set
      img_ds = loader1.get_image_ds().repeat()
      masks_ds = loader1.get_mask_ds().repeat()
      label_ds = loader1.get_binary_ds().repeat()
      bbox_ds = loader1.get_bboxes_ds().repeat()

      # Validation set
      img_ds_val = loader2.get_image_ds().repeat()
      masks_ds_val = loader2.get_mask_ds().repeat()
      label_ds_val = loader2.get_binary_ds().repeat()
      bbox_ds_val = loader2.get_bboxes_ds().repeat()
      
      model = build_model(img_height, img_width, channels)

      model.compile(optimizer=keras.optimizers.Adam(1e-4),
                  loss={'segnet_out' : tf.keras.losses.BinaryCrossentropy(from_logits=True),
                        'bbox_out' : tf.keras.losses.MeanAbsoluteError()},
                  loss_weights=[1,1/100], # Scale MAE to BC range
                  metrics=['accuracy'])

      print(f"-------------------- start cross val {cv_iter+1}/{CVfolds} --------------------")

      history = model.fit(generator_img(img_ds, masks_ds, bbox_ds), 
                        validation_data=generator_img_val(img_ds_val, masks_ds_val, bbox_ds), 
                        epochs=ep, 
                        steps_per_epoch=num_train_cv//batch_size, 
                        validation_steps=num_val_cv//batch_size_val)

      # save the final val_acc of each cv step
      cv_history.append(history.history)
# Out:
# -------------------- start cross val 1/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 93s 363ms/step - loss: 1.5671 - segnet_out_loss: 0.4603 - bbox_out_loss: 110.6757 - segnet_out_accuracy: 0.7841 - bbox_out_accuracy: 0.2709 - val_loss: 1.3625 - val_segnet_out_loss: 0.2377 - val_bbox_out_loss: 112.4803 - val_segnet_out_accuracy: 0.9310 - val_bbox_out_accuracy: 0.3318
# Epoch 2/10
# 221/221 [==============================] - 74s 336ms/step - loss: 1.2948 - segnet_out_loss: 0.2116 - bbox_out_loss: 108.3163 - segnet_out_accuracy: 0.9327 - bbox_out_accuracy: 0.3773 - val_loss: 1.2195 - val_segnet_out_loss: 0.1643 - val_bbox_out_loss: 105.5202 - val_segnet_out_accuracy: 0.9471 - val_bbox_out_accuracy: 0.4023
# Epoch 3/10
# 221/221 [==============================] - 74s 336ms/step - loss: 1.1865 - segnet_out_loss: 0.1515 - bbox_out_loss: 103.4924 - segnet_out_accuracy: 0.9531 - bbox_out_accuracy: 0.4553 - val_loss: 1.1504 - val_segnet_out_loss: 0.1427 - val_bbox_out_loss: 100.7709 - val_segnet_out_accuracy: 0.9507 - val_bbox_out_accuracy: 0.4432
# Epoch 4/10
# 221/221 [==============================] - 76s 346ms/step - loss: 1.0860 - segnet_out_loss: 0.1239 - bbox_out_loss: 96.2112 - segnet_out_accuracy: 0.9603 - bbox_out_accuracy: 0.4621 - val_loss: 1.0479 - val_segnet_out_loss: 0.1314 - val_bbox_out_loss: 91.6532 - val_segnet_out_accuracy: 0.9536 - val_bbox_out_accuracy: 0.4205
# Epoch 5/10
# 221/221 [==============================] - 75s 338ms/step - loss: 0.9766 - segnet_out_loss: 0.1085 - bbox_out_loss: 86.8150 - segnet_out_accuracy: 0.9639 - bbox_out_accuracy: 0.4610 - val_loss: 0.9677 - val_segnet_out_loss: 0.1259 - val_bbox_out_loss: 84.1779 - val_segnet_out_accuracy: 0.9537 - val_bbox_out_accuracy: 0.4682
# Epoch 6/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.8570 - segnet_out_loss: 0.0976 - bbox_out_loss: 75.9451 - segnet_out_accuracy: 0.9669 - bbox_out_accuracy: 0.4548 - val_loss: 0.8702 - val_segnet_out_loss: 0.1222 - val_bbox_out_loss: 74.8018 - val_segnet_out_accuracy: 0.9558 - val_bbox_out_accuracy: 0.4500
# Epoch 7/10
# 221/221 [==============================] - 75s 338ms/step - loss: 0.7346 - segnet_out_loss: 0.0900 - bbox_out_loss: 64.4578 - segnet_out_accuracy: 0.9690 - bbox_out_accuracy: 0.4972 - val_loss: 0.7809 - val_segnet_out_loss: 0.1213 - val_bbox_out_loss: 65.9592 - val_segnet_out_accuracy: 0.9559 - val_bbox_out_accuracy: 0.5523
# Epoch 8/10
# 221/221 [==============================] - 75s 341ms/step - loss: 0.6168 - segnet_out_loss: 0.0842 - bbox_out_loss: 53.2580 - segnet_out_accuracy: 0.9707 - bbox_out_accuracy: 0.5419 - val_loss: 0.6616 - val_segnet_out_loss: 0.1199 - val_bbox_out_loss: 54.1682 - val_segnet_out_accuracy: 0.9563 - val_bbox_out_accuracy: 0.5773
# Epoch 9/10
# 221/221 [==============================] - 75s 340ms/step - loss: 0.5114 - segnet_out_loss: 0.0800 - bbox_out_loss: 43.1363 - segnet_out_accuracy: 0.9720 - bbox_out_accuracy: 0.6324 - val_loss: 0.6372 - val_segnet_out_loss: 0.1214 - val_bbox_out_loss: 51.5786 - val_segnet_out_accuracy: 0.9559 - val_bbox_out_accuracy: 0.6114
# Epoch 10/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.4132 - segnet_out_loss: 0.0757 - bbox_out_loss: 33.7427 - segnet_out_accuracy: 0.9734 - bbox_out_accuracy: 0.6861 - val_loss: 0.5398 - val_segnet_out_loss: 0.1217 - val_bbox_out_loss: 41.8144 - val_segnet_out_accuracy: 0.9563 - val_bbox_out_accuracy: 0.5955
# -------------------- start cross val 2/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 81s 339ms/step - loss: 1.5221 - segnet_out_loss: 0.4202 - bbox_out_loss: 110.1892 - segnet_out_accuracy: 0.8031 - bbox_out_accuracy: 0.2613 - val_loss: 1.3156 - val_segnet_out_loss: 0.2153 - val_bbox_out_loss: 110.0324 - val_segnet_out_accuracy: 0.9390 - val_bbox_out_accuracy: 0.3773
# Epoch 2/10
# 221/221 [==============================] - 74s 336ms/step - loss: 1.2741 - segnet_out_loss: 0.1955 - bbox_out_loss: 107.8606 - segnet_out_accuracy: 0.9383 - bbox_out_accuracy: 0.4016 - val_loss: 1.2098 - val_segnet_out_loss: 0.1536 - val_bbox_out_loss: 105.6204 - val_segnet_out_accuracy: 0.9500 - val_bbox_out_accuracy: 0.4886
# Epoch 3/10
# 221/221 [==============================] - 76s 344ms/step - loss: 1.1740 - segnet_out_loss: 0.1432 - bbox_out_loss: 103.0783 - segnet_out_accuracy: 0.9544 - bbox_out_accuracy: 0.5023 - val_loss: 1.1319 - val_segnet_out_loss: 0.1329 - val_bbox_out_loss: 99.8990 - val_segnet_out_accuracy: 0.9539 - val_bbox_out_accuracy: 0.5727
# Epoch 4/10
# 221/221 [==============================] - 75s 342ms/step - loss: 1.0777 - segnet_out_loss: 0.1192 - bbox_out_loss: 95.8503 - segnet_out_accuracy: 0.9605 - bbox_out_accuracy: 0.5028 - val_loss: 1.0341 - val_segnet_out_loss: 0.1230 - val_bbox_out_loss: 91.1110 - val_segnet_out_accuracy: 0.9553 - val_bbox_out_accuracy: 0.5227
# Epoch 5/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.9707 - segnet_out_loss: 0.1054 - bbox_out_loss: 86.5330 - segnet_out_accuracy: 0.9641 - bbox_out_accuracy: 0.5045 - val_loss: 0.9490 - val_segnet_out_loss: 0.1177 - val_bbox_out_loss: 83.1245 - val_segnet_out_accuracy: 0.9562 - val_bbox_out_accuracy: 0.5114
# Epoch 6/10
# 221/221 [==============================] - 76s 345ms/step - loss: 0.8531 - segnet_out_loss: 0.0961 - bbox_out_loss: 75.7035 - segnet_out_accuracy: 0.9666 - bbox_out_accuracy: 0.5090 - val_loss: 0.8281 - val_segnet_out_loss: 0.1140 - val_bbox_out_loss: 71.4118 - val_segnet_out_accuracy: 0.9581 - val_bbox_out_accuracy: 0.5727
# Epoch 7/10
# 221/221 [==============================] - 76s 343ms/step - loss: 0.7310 - segnet_out_loss: 0.0884 - bbox_out_loss: 64.2571 - segnet_out_accuracy: 0.9691 - bbox_out_accuracy: 0.5526 - val_loss: 0.7376 - val_segnet_out_loss: 0.1141 - val_bbox_out_loss: 62.3438 - val_segnet_out_accuracy: 0.9575 - val_bbox_out_accuracy: 0.5318
# Epoch 8/10
# 221/221 [==============================] - 74s 335ms/step - loss: 0.6130 - segnet_out_loss: 0.0828 - bbox_out_loss: 53.0203 - segnet_out_accuracy: 0.9708 - bbox_out_accuracy: 0.6086 - val_loss: 0.6597 - val_segnet_out_loss: 0.1152 - val_bbox_out_loss: 54.4494 - val_segnet_out_accuracy: 0.9569 - val_bbox_out_accuracy: 0.6045
# Epoch 9/10
# 221/221 [==============================] - 75s 340ms/step - loss: 0.5042 - segnet_out_loss: 0.0784 - bbox_out_loss: 42.5809 - segnet_out_accuracy: 0.9723 - bbox_out_accuracy: 0.6635 - val_loss: 0.5936 - val_segnet_out_loss: 0.1149 - val_bbox_out_loss: 47.8704 - val_segnet_out_accuracy: 0.9569 - val_bbox_out_accuracy: 0.6023
# Epoch 10/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.4074 - segnet_out_loss: 0.0751 - bbox_out_loss: 33.2281 - segnet_out_accuracy: 0.9733 - bbox_out_accuracy: 0.6951 - val_loss: 0.5507 - val_segnet_out_loss: 0.1182 - val_bbox_out_loss: 43.2496 - val_segnet_out_accuracy: 0.9560 - val_bbox_out_accuracy: 0.5909
# -------------------- start cross val 3/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 82s 345ms/step - loss: 1.5630 - segnet_out_loss: 0.4532 - bbox_out_loss: 110.9767 - segnet_out_accuracy: 0.7857 - bbox_out_accuracy: 0.2523 - val_loss: 1.3381 - val_segnet_out_loss: 0.2345 - val_bbox_out_loss: 110.3609 - val_segnet_out_accuracy: 0.9346 - val_bbox_out_accuracy: 0.2909
# Epoch 2/10
# 221/221 [==============================] - 75s 338ms/step - loss: 1.2898 - segnet_out_loss: 0.2033 - bbox_out_loss: 108.6502 - segnet_out_accuracy: 0.9368 - bbox_out_accuracy: 0.3484 - val_loss: 1.2562 - val_segnet_out_loss: 0.1671 - val_bbox_out_loss: 108.9118 - val_segnet_out_accuracy: 0.9462 - val_bbox_out_accuracy: 0.3955
# Epoch 3/10
# 221/221 [==============================] - 76s 344ms/step - loss: 1.1852 - segnet_out_loss: 0.1464 - bbox_out_loss: 103.8812 - segnet_out_accuracy: 0.9549 - bbox_out_accuracy: 0.4893 - val_loss: 1.1565 - val_segnet_out_loss: 0.1470 - val_bbox_out_loss: 100.9469 - val_segnet_out_accuracy: 0.9502 - val_bbox_out_accuracy: 0.5091
# Epoch 4/10
# 221/221 [==============================] - 77s 349ms/step - loss: 1.0866 - segnet_out_loss: 0.1203 - bbox_out_loss: 96.6243 - segnet_out_accuracy: 0.9614 - bbox_out_accuracy: 0.5351 - val_loss: 1.0448 - val_segnet_out_loss: 0.1388 - val_bbox_out_loss: 90.5967 - val_segnet_out_accuracy: 0.9506 - val_bbox_out_accuracy: 0.5341
# Epoch 5/10
# 221/221 [==============================] - 75s 342ms/step - loss: 0.9760 - segnet_out_loss: 0.1037 - bbox_out_loss: 87.2361 - segnet_out_accuracy: 0.9658 - bbox_out_accuracy: 0.5300 - val_loss: 0.9586 - val_segnet_out_loss: 0.1347 - val_bbox_out_loss: 82.3857 - val_segnet_out_accuracy: 0.9519 - val_bbox_out_accuracy: 0.5614
# Epoch 6/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.8564 - segnet_out_loss: 0.0940 - bbox_out_loss: 76.2393 - segnet_out_accuracy: 0.9681 - bbox_out_accuracy: 0.5526 - val_loss: 0.8751 - val_segnet_out_loss: 0.1331 - val_bbox_out_loss: 74.1920 - val_segnet_out_accuracy: 0.9519 - val_bbox_out_accuracy: 0.5591
# Epoch 7/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.7351 - segnet_out_loss: 0.0870 - bbox_out_loss: 64.8132 - segnet_out_accuracy: 0.9701 - bbox_out_accuracy: 0.5809 - val_loss: 0.7854 - val_segnet_out_loss: 0.1314 - val_bbox_out_loss: 65.4013 - val_segnet_out_accuracy: 0.9524 - val_bbox_out_accuracy: 0.5977
# Epoch 8/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.6160 - segnet_out_loss: 0.0817 - bbox_out_loss: 53.4255 - segnet_out_accuracy: 0.9715 - bbox_out_accuracy: 0.6250 - val_loss: 0.6993 - val_segnet_out_loss: 0.1293 - val_bbox_out_loss: 56.9946 - val_segnet_out_accuracy: 0.9533 - val_bbox_out_accuracy: 0.6227
# Epoch 9/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.5065 - segnet_out_loss: 0.0778 - bbox_out_loss: 42.8685 - segnet_out_accuracy: 0.9728 - bbox_out_accuracy: 0.6550 - val_loss: 0.6219 - val_segnet_out_loss: 0.1309 - val_bbox_out_loss: 49.0985 - val_segnet_out_accuracy: 0.9529 - val_bbox_out_accuracy: 0.6182
# Epoch 10/10
# 221/221 [==============================] - 79s 360ms/step - loss: 0.4055 - segnet_out_loss: 0.0742 - bbox_out_loss: 33.1340 - segnet_out_accuracy: 0.9739 - bbox_out_accuracy: 0.6957 - val_loss: 0.5735 - val_segnet_out_loss: 0.1326 - val_bbox_out_loss: 44.0851 - val_segnet_out_accuracy: 0.9528 - val_bbox_out_accuracy: 0.6341
# -------------------- start cross val 4/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 90s 380ms/step - loss: 1.5686 - segnet_out_loss: 0.4615 - bbox_out_loss: 110.7053 - segnet_out_accuracy: 0.8000 - bbox_out_accuracy: 0.2822 - val_loss: 1.3333 - val_segnet_out_loss: 0.2308 - val_bbox_out_loss: 110.2519 - val_segnet_out_accuracy: 0.9409 - val_bbox_out_accuracy: 0.3864
# Epoch 2/10
# 221/221 [==============================] - 99s 448ms/step - loss: 1.2931 - segnet_out_loss: 0.2087 - bbox_out_loss: 108.4343 - segnet_out_accuracy: 0.9354 - bbox_out_accuracy: 0.4152 - val_loss: 1.2454 - val_segnet_out_loss: 0.1611 - val_bbox_out_loss: 108.4331 - val_segnet_out_accuracy: 0.9505 - val_bbox_out_accuracy: 0.5295
# Epoch 3/10
# 221/221 [==============================] - 101s 458ms/step - loss: 1.1880 - segnet_out_loss: 0.1506 - bbox_out_loss: 103.7387 - segnet_out_accuracy: 0.9543 - bbox_out_accuracy: 0.5017 - val_loss: 1.1416 - val_segnet_out_loss: 0.1412 - val_bbox_out_loss: 100.0447 - val_segnet_out_accuracy: 0.9533 - val_bbox_out_accuracy: 0.5318
# Epoch 4/10
# 221/221 [==============================] - 100s 454ms/step - loss: 1.0890 - segnet_out_loss: 0.1231 - bbox_out_loss: 96.5833 - segnet_out_accuracy: 0.9610 - bbox_out_accuracy: 0.5175 - val_loss: 1.0580 - val_segnet_out_loss: 0.1293 - val_bbox_out_loss: 92.8669 - val_segnet_out_accuracy: 0.9562 - val_bbox_out_accuracy: 0.5409
# Epoch 5/10
# 221/221 [==============================] - 101s 460ms/step - loss: 0.9801 - segnet_out_loss: 0.1069 - bbox_out_loss: 87.3161 - segnet_out_accuracy: 0.9649 - bbox_out_accuracy: 0.5175 - val_loss: 0.9435 - val_segnet_out_loss: 0.1221 - val_bbox_out_loss: 82.1457 - val_segnet_out_accuracy: 0.9568 - val_bbox_out_accuracy: 0.5409
# Epoch 6/10
# 221/221 [==============================] - 101s 458ms/step - loss: 0.8609 - segnet_out_loss: 0.0963 - bbox_out_loss: 76.4653 - segnet_out_accuracy: 0.9678 - bbox_out_accuracy: 0.5153 - val_loss: 0.8507 - val_segnet_out_loss: 0.1216 - val_bbox_out_loss: 72.9094 - val_segnet_out_accuracy: 0.9569 - val_bbox_out_accuracy: 0.5614
# Epoch 7/10
# 221/221 [==============================] - 101s 457ms/step - loss: 0.7392 - segnet_out_loss: 0.0894 - bbox_out_loss: 64.9812 - segnet_out_accuracy: 0.9695 - bbox_out_accuracy: 0.5628 - val_loss: 0.7435 - val_segnet_out_loss: 0.1177 - val_bbox_out_loss: 62.5870 - val_segnet_out_accuracy: 0.9579 - val_bbox_out_accuracy: 0.5886
# Epoch 8/10
# 221/221 [==============================] - 101s 458ms/step - loss: 0.6196 - segnet_out_loss: 0.0828 - bbox_out_loss: 53.6879 - segnet_out_accuracy: 0.9715 - bbox_out_accuracy: 0.6143 - val_loss: 0.6489 - val_segnet_out_loss: 0.1185 - val_bbox_out_loss: 53.0392 - val_segnet_out_accuracy: 0.9576 - val_bbox_out_accuracy: 0.6568
# Epoch 9/10
# 221/221 [==============================] - 106s 479ms/step - loss: 0.5109 - segnet_out_loss: 0.0786 - bbox_out_loss: 43.2377 - segnet_out_accuracy: 0.9727 - bbox_out_accuracy: 0.6516 - val_loss: 0.5851 - val_segnet_out_loss: 0.1170 - val_bbox_out_loss: 46.8120 - val_segnet_out_accuracy: 0.9582 - val_bbox_out_accuracy: 0.6182
# Epoch 10/10
# 221/221 [==============================] - 151s 683ms/step - loss: 0.4107 - segnet_out_loss: 0.0755 - bbox_out_loss: 33.5225 - segnet_out_accuracy: 0.9736 - bbox_out_accuracy: 0.6799 - val_loss: 0.5504 - val_segnet_out_loss: 0.1186 - val_bbox_out_loss: 43.1887 - val_segnet_out_accuracy: 0.9581 - val_bbox_out_accuracy: 0.6068
# -------------------- start cross val 5/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 676s 3s/step - loss: 1.5341 - segnet_out_loss: 0.4222 - bbox_out_loss: 111.1881 - segnet_out_accuracy: 0.7986 - bbox_out_accuracy: 0.2743 - val_loss: 1.3308 - val_segnet_out_loss: 0.2273 - val_bbox_out_loss: 110.3420 - val_segnet_out_accuracy: 0.9280 - val_bbox_out_accuracy: 0.3182
# Epoch 2/10
# 221/221 [==============================] - 117s 528ms/step - loss: 1.2901 - segnet_out_loss: 0.2000 - bbox_out_loss: 109.0086 - segnet_out_accuracy: 0.9366 - bbox_out_accuracy: 0.3959 - val_loss: 1.2505 - val_segnet_out_loss: 0.1646 - val_bbox_out_loss: 108.5883 - val_segnet_out_accuracy: 0.9463 - val_bbox_out_accuracy: 0.4432
# Epoch 3/10
# 221/221 [==============================] - 100s 454ms/step - loss: 1.1885 - segnet_out_loss: 0.1463 - bbox_out_loss: 104.2226 - segnet_out_accuracy: 0.9544 - bbox_out_accuracy: 0.4598 - val_loss: 1.1543 - val_segnet_out_loss: 0.1431 - val_bbox_out_loss: 101.1213 - val_segnet_out_accuracy: 0.9502 - val_bbox_out_accuracy: 0.4341
# Epoch 4/10
# 221/221 [==============================] - 99s 449ms/step - loss: 1.0886 - segnet_out_loss: 0.1198 - bbox_out_loss: 96.8795 - segnet_out_accuracy: 0.9615 - bbox_out_accuracy: 0.4853 - val_loss: 1.0478 - val_segnet_out_loss: 0.1389 - val_bbox_out_loss: 90.8893 - val_segnet_out_accuracy: 0.9494 - val_bbox_out_accuracy: 0.4432
# Epoch 5/10
# 221/221 [==============================] - 99s 449ms/step - loss: 0.9787 - segnet_out_loss: 0.1044 - bbox_out_loss: 87.4274 - segnet_out_accuracy: 0.9654 - bbox_out_accuracy: 0.4745 - val_loss: 0.9522 - val_segnet_out_loss: 0.1300 - val_bbox_out_loss: 82.2220 - val_segnet_out_accuracy: 0.9532 - val_bbox_out_accuracy: 0.4955
# Epoch 6/10
# 221/221 [==============================] - 99s 448ms/step - loss: 0.8595 - segnet_out_loss: 0.0944 - bbox_out_loss: 76.5065 - segnet_out_accuracy: 0.9680 - bbox_out_accuracy: 0.5085 - val_loss: 0.8839 - val_segnet_out_loss: 0.1286 - val_bbox_out_loss: 75.5292 - val_segnet_out_accuracy: 0.9534 - val_bbox_out_accuracy: 0.5568
# Epoch 7/10
# 221/221 [==============================] - 98s 447ms/step - loss: 0.7360 - segnet_out_loss: 0.0880 - bbox_out_loss: 64.8037 - segnet_out_accuracy: 0.9697 - bbox_out_accuracy: 0.5198 - val_loss: 0.7939 - val_segnet_out_loss: 0.1277 - val_bbox_out_loss: 66.6248 - val_segnet_out_accuracy: 0.9535 - val_bbox_out_accuracy: 0.5068
# Epoch 8/10
# 221/221 [==============================] - 101s 458ms/step - loss: 0.6154 - segnet_out_loss: 0.0813 - bbox_out_loss: 53.4075 - segnet_out_accuracy: 0.9718 - bbox_out_accuracy: 0.5730 - val_loss: 0.6893 - val_segnet_out_loss: 0.1300 - val_bbox_out_loss: 55.9302 - val_segnet_out_accuracy: 0.9527 - val_bbox_out_accuracy: 0.5705
# Epoch 9/10
# 221/221 [==============================] - 101s 457ms/step - loss: 0.5048 - segnet_out_loss: 0.0768 - bbox_out_loss: 42.7972 - segnet_out_accuracy: 0.9733 - bbox_out_accuracy: 0.6465 - val_loss: 0.6000 - val_segnet_out_loss: 0.1267 - val_bbox_out_loss: 47.3292 - val_segnet_out_accuracy: 0.9540 - val_bbox_out_accuracy: 0.5864
# Epoch 10/10
# 221/221 [==============================] - 100s 455ms/step - loss: 0.4055 - segnet_out_loss: 0.0741 - bbox_out_loss: 33.1414 - segnet_out_accuracy: 0.9739 - bbox_out_accuracy: 0.6963 - val_loss: 0.5726 - val_segnet_out_loss: 0.1279 - val_bbox_out_loss: 44.4675 - val_segnet_out_accuracy: 0.9545 - val_bbox_out_accuracy: 0.5523

# %%
# extract the wanted metrics
result = []
for i in range(CVfolds):
    result.append([cv_history[i]['segnet_out_accuracy'],
                    cv_history[i]['val_segnet_out_accuracy']])

# %%
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(CVfolds):
    ax.plot(result[i][0], linestyle=":", label = f"segment acc, cv {i}")
for i in range(CVfolds):
    ax.plot(result[i][1], linestyle="-", label = f"val segment acc, cv {i}")
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('MTL with segmentation and bbox')
plt.legend()
plt.ylim([0.75, 1])
plt.grid()
plt.show()

# %%
# Print out the results to see offline
print("set \tsegmen ")
for i in range(CVfolds):
    print(f"CV {i+1} \t{np.round(result[i][1][-1], 4)}")

print("-----------------------------")
avg = np.round(np.mean(result, axis=0), 4)
std = np.round(np.std(result, axis=0), 4)
print(f"Avg  \t{avg[1][-1]} ")
print(f"Std  \t{std[1][-1]} ")
# Out:
# set 	segmen
# CV 1 	0.9563
# CV 2 	0.956
# CV 3 	0.9528
# CV 4 	0.9581
# CV 5 	0.9545
# -----------------------------
# Avg  	0.9555
# Std  	0.0018
