# %% [markdown]
# # Intro of this file
# + Heads: segmentation + binary
# + Performs 5 fold cv (main args might want to change: batchsize=8, fold=5, ep=10)
# + To change the fold numbers, simply change "CVfolds" in the section "Start cross validation"
# + loader and train is modified compared to the main branch

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
import numpy as np
import random
import matplotlib.pyplot as plt

from utils.loader import DataLoader
from models.effnet_encoder import EffnetEncoder
from models.mtl_framework import MTLFramework
from utils import tools, config

# %%
# Set configs
batch_size = 8
batch_size_val = 8
num_train, num_val, num_test = config.config['num_train'], config.config['num_val'], config.config['num_test']
img_height, img_width, channels = config.config['input_shape']

# %% [markdown]
# ### Build our MTL

# %%
def build_model(img_height, img_width, channels):
    ### CLEARS OLD MODELS IN CACHE
    tf.keras.backend.clear_session()

    # Get encoder
    base_model_name = 'B0'
    encoder = EffnetEncoder(base_model_name, (img_height, img_width, channels)).build_encoder(trainable=True)

    # Use our MTL framework to custom build a model
    mtl_builder = MTLFramework(encoder, (img_height, img_width, channels))
    mtl_builder.add_segmentation_head()
    mtl_builder.add_binary_classification_head(base_model_name, trainable=True)
    # mtl_builder.add_bbox_classification_head(base_model_name, trainable=True)
    model = mtl_builder.build_mtl_model()

    return model

# %% [markdown]
# ### Train model

# %%
def generator_img(img_ds, masks_ds, label_ds):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds.as_numpy_iterator()
    b = masks_ds.as_numpy_iterator()
    c = label_ds.as_numpy_iterator()
    # d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        Y2 = c.next()
        # Y3 = d.next()
        
        # Regularisation and shuffling
        X, Y1, Y2 = tools.get_randomised_data([X, Y1, Y2])
        # X, Y1, Y3 = tools.data_augmentation(X, Y1, Y3) # Fix augmentation
        
        yield X, (Y1, Y2)

# %%
def generator_img_val(img_ds_val, masks_ds_val, label_ds_val):
    ''' Merges together datasets into a unified generator to pass for training '''
    a = img_ds_val.as_numpy_iterator()
    b = masks_ds_val.as_numpy_iterator()
    c = label_ds_val.as_numpy_iterator()
    # d = bbox_ds.as_numpy_iterator()
    
    while True:
        X = a.next()
        Y1 = b.next()
        Y2 = c.next()
        # Y3 = d.next()
        
        yield X, (Y1, Y2)

# %% [markdown]
# ### Start cross validation

# %%
##### Change this to modify the folds #####
CVfolds = 5
ep = 10
###########################################
cv_history = []
num_train_cv = num_train * (CVfolds-1)/CVfolds
num_val_cv = num_train * 1/CVfolds

for cv_iter in range(CVfolds):
      # CrossVal: 0 = no CV, 1 = training set, 2 = val set
      loader1 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=1, CV_iteration=cv_iter, fold=CVfolds)
      loader2 = DataLoader(batch_size=batch_size, batch_size_val=batch_size_val, CrossVal=2, CV_iteration=cv_iter, fold=CVfolds)

      # Train set
      img_ds = loader1.get_image_ds().repeat()
      masks_ds = loader1.get_mask_ds().repeat()
      label_ds = loader1.get_binary_ds().repeat()
      bbox_ds = loader1.get_bboxes_ds().repeat()

      # Validation set
      img_ds_val = loader2.get_image_ds().repeat()
      masks_ds_val = loader2.get_mask_ds().repeat()
      label_ds_val = loader2.get_binary_ds().repeat()
      bbox_ds_val = loader2.get_bboxes_ds().repeat()
      
      model = build_model(img_height, img_width, channels)

      model.compile(optimizer=keras.optimizers.Adam(1e-4),
                  loss={'segnet_out' : tf.keras.losses.BinaryCrossentropy(from_logits=True),
                        'bin_class_out' : tf.keras.losses.BinaryCrossentropy()},
                  loss_weights=[1,1], # Scale MAE to BC range
                  metrics=['accuracy'])

      print(f"-------------------- start cross val {cv_iter+1}/{CVfolds} --------------------")

      history = model.fit(generator_img(img_ds, masks_ds, label_ds), 
                        validation_data=generator_img_val(img_ds_val, masks_ds_val, label_ds_val), 
                        epochs=ep, 
                        steps_per_epoch=num_train_cv//batch_size, 
                        validation_steps=num_val_cv//batch_size_val)

      # save the final val_acc of each cv step
      cv_history.append(history.history)
# Out:
# -------------------- start cross val 1/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 115s 464ms/step - loss: 0.7077 - segnet_out_loss: 0.4757 - bin_class_out_loss: 0.2320 - segnet_out_accuracy: 0.7747 - bin_class_out_accuracy: 0.9163 - val_loss: 0.2973 - val_segnet_out_loss: 0.2637 - val_bin_class_out_loss: 0.0336 - val_segnet_out_accuracy: 0.9050 - val_bin_class_out_accuracy: 0.9886
# Epoch 2/10
# 221/221 [==============================] - 97s 439ms/step - loss: 0.2779 - segnet_out_loss: 0.2307 - bin_class_out_loss: 0.0471 - segnet_out_accuracy: 0.9192 - bin_class_out_accuracy: 0.9898 - val_loss: 0.2173 - val_segnet_out_loss: 0.1860 - val_bin_class_out_loss: 0.0314 - val_segnet_out_accuracy: 0.9325 - val_bin_class_out_accuracy: 0.9909
# Epoch 3/10
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1936 - segnet_out_loss: 0.1764 - bin_class_out_loss: 0.0172 - segnet_out_accuracy: 0.9393 - bin_class_out_accuracy: 0.9966 - val_loss: 0.1833 - val_segnet_out_loss: 0.1549 - val_bin_class_out_loss: 0.0284 - val_segnet_out_accuracy: 0.9422 - val_bin_class_out_accuracy: 0.9932
# Epoch 4/10
# 221/221 [==============================] - 97s 441ms/step - loss: 0.1572 - segnet_out_loss: 0.1469 - bin_class_out_loss: 0.0104 - segnet_out_accuracy: 0.9486 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1560 - val_segnet_out_loss: 0.1404 - val_bin_class_out_loss: 0.0156 - val_segnet_out_accuracy: 0.9472 - val_bin_class_out_accuracy: 0.9932
# Epoch 5/10
# 221/221 [==============================] - 88s 397ms/step - loss: 0.1353 - segnet_out_loss: 0.1288 - bin_class_out_loss: 0.0065 - segnet_out_accuracy: 0.9542 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1553 - val_segnet_out_loss: 0.1328 - val_bin_class_out_loss: 0.0226 - val_segnet_out_accuracy: 0.9497 - val_bin_class_out_accuracy: 0.9886
# Epoch 6/10
# 221/221 [==============================] - 76s 344ms/step - loss: 0.1213 - segnet_out_loss: 0.1161 - bin_class_out_loss: 0.0052 - segnet_out_accuracy: 0.9584 - bin_class_out_accuracy: 0.9989 - val_loss: 0.1525 - val_segnet_out_loss: 0.1291 - val_bin_class_out_loss: 0.0233 - val_segnet_out_accuracy: 0.9518 - val_bin_class_out_accuracy: 0.9886
# Epoch 7/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.1099 - segnet_out_loss: 0.1061 - bin_class_out_loss: 0.0038 - segnet_out_accuracy: 0.9617 - bin_class_out_accuracy: 0.9989 - val_loss: 0.1753 - val_segnet_out_loss: 0.1283 - val_bin_class_out_loss: 0.0471 - val_segnet_out_accuracy: 0.9519 - val_bin_class_out_accuracy: 0.9841
# Epoch 8/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.1026 - segnet_out_loss: 0.0986 - bin_class_out_loss: 0.0040 - segnet_out_accuracy: 0.9644 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1501 - val_segnet_out_loss: 0.1264 - val_bin_class_out_loss: 0.0237 - val_segnet_out_accuracy: 0.9538 - val_bin_class_out_accuracy: 0.9841
# Epoch 9/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.0940 - segnet_out_loss: 0.0913 - bin_class_out_loss: 0.0027 - segnet_out_accuracy: 0.9670 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1523 - val_segnet_out_loss: 0.1270 - val_bin_class_out_loss: 0.0253 - val_segnet_out_accuracy: 0.9528 - val_bin_class_out_accuracy: 0.9886
# Epoch 10/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.0872 - segnet_out_loss: 0.0857 - bin_class_out_loss: 0.0015 - segnet_out_accuracy: 0.9691 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1395 - val_segnet_out_loss: 0.1260 - val_bin_class_out_loss: 0.0136 - val_segnet_out_accuracy: 0.9538 - val_bin_class_out_accuracy: 0.9932
# -------------------- start cross val 2/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 80s 339ms/step - loss: 0.7939 - segnet_out_loss: 0.5770 - bin_class_out_loss: 0.2169 - segnet_out_accuracy: 0.7417 - bin_class_out_accuracy: 0.9236 - val_loss: 0.3115 - val_segnet_out_loss: 0.2852 - val_bin_class_out_loss: 0.0263 - val_segnet_out_accuracy: 0.9098 - val_bin_class_out_accuracy: 0.9955
# Epoch 2/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.2890 - segnet_out_loss: 0.2527 - bin_class_out_loss: 0.0363 - segnet_out_accuracy: 0.9142 - bin_class_out_accuracy: 0.9938 - val_loss: 0.2220 - val_segnet_out_loss: 0.1889 - val_bin_class_out_loss: 0.0331 - val_segnet_out_accuracy: 0.9372 - val_bin_class_out_accuracy: 0.9841
# Epoch 3/10
# 221/221 [==============================] - 74s 334ms/step - loss: 0.2068 - segnet_out_loss: 0.1865 - bin_class_out_loss: 0.0203 - segnet_out_accuracy: 0.9379 - bin_class_out_accuracy: 0.9955 - val_loss: 0.1758 - val_segnet_out_loss: 0.1527 - val_bin_class_out_loss: 0.0231 - val_segnet_out_accuracy: 0.9481 - val_bin_class_out_accuracy: 0.9886
# Epoch 4/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.1675 - segnet_out_loss: 0.1542 - bin_class_out_loss: 0.0133 - segnet_out_accuracy: 0.9474 - bin_class_out_accuracy: 0.9972 - val_loss: 0.1568 - val_segnet_out_loss: 0.1396 - val_bin_class_out_loss: 0.0171 - val_segnet_out_accuracy: 0.9495 - val_bin_class_out_accuracy: 0.9955
# Epoch 5/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.1412 - segnet_out_loss: 0.1336 - bin_class_out_loss: 0.0076 - segnet_out_accuracy: 0.9536 - bin_class_out_accuracy: 0.9989 - val_loss: 0.1443 - val_segnet_out_loss: 0.1293 - val_bin_class_out_loss: 0.0150 - val_segnet_out_accuracy: 0.9532 - val_bin_class_out_accuracy: 0.9977
# Epoch 6/10
# 221/221 [==============================] - 74s 334ms/step - loss: 0.1220 - segnet_out_loss: 0.1187 - bin_class_out_loss: 0.0033 - segnet_out_accuracy: 0.9583 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1346 - val_segnet_out_loss: 0.1230 - val_bin_class_out_loss: 0.0116 - val_segnet_out_accuracy: 0.9553 - val_bin_class_out_accuracy: 1.0000
# Epoch 7/10
# 221/221 [==============================] - 73s 333ms/step - loss: 0.1174 - segnet_out_loss: 0.1089 - bin_class_out_loss: 0.0085 - segnet_out_accuracy: 0.9612 - bin_class_out_accuracy: 0.9966 - val_loss: 0.1429 - val_segnet_out_loss: 0.1232 - val_bin_class_out_loss: 0.0197 - val_segnet_out_accuracy: 0.9541 - val_bin_class_out_accuracy: 0.9932
# Epoch 8/10
# 221/221 [==============================] - 73s 333ms/step - loss: 0.1097 - segnet_out_loss: 0.1013 - bin_class_out_loss: 0.0083 - segnet_out_accuracy: 0.9638 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1370 - val_segnet_out_loss: 0.1201 - val_bin_class_out_loss: 0.0170 - val_segnet_out_accuracy: 0.9555 - val_bin_class_out_accuracy: 0.9932
# Epoch 9/10
# 221/221 [==============================] - 74s 335ms/step - loss: 0.0966 - segnet_out_loss: 0.0935 - bin_class_out_loss: 0.0031 - segnet_out_accuracy: 0.9666 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1339 - val_segnet_out_loss: 0.1186 - val_bin_class_out_loss: 0.0153 - val_segnet_out_accuracy: 0.9563 - val_bin_class_out_accuracy: 0.9955
# Epoch 10/10
# 221/221 [==============================] - 73s 332ms/step - loss: 0.0891 - segnet_out_loss: 0.0869 - bin_class_out_loss: 0.0022 - segnet_out_accuracy: 0.9690 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1325 - val_segnet_out_loss: 0.1188 - val_bin_class_out_loss: 0.0137 - val_segnet_out_accuracy: 0.9559 - val_bin_class_out_accuracy: 0.9977
# -------------------- start cross val 3/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 81s 340ms/step - loss: 0.6735 - segnet_out_loss: 0.4476 - bin_class_out_loss: 0.2259 - segnet_out_accuracy: 0.7942 - bin_class_out_accuracy: 0.9174 - val_loss: 0.2894 - val_segnet_out_loss: 0.2583 - val_bin_class_out_loss: 0.0311 - val_segnet_out_accuracy: 0.9203 - val_bin_class_out_accuracy: 0.9932
# Epoch 2/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.2616 - segnet_out_loss: 0.2227 - bin_class_out_loss: 0.0389 - segnet_out_accuracy: 0.9241 - bin_class_out_accuracy: 0.9926 - val_loss: 0.2109 - val_segnet_out_loss: 0.1816 - val_bin_class_out_loss: 0.0293 - val_segnet_out_accuracy: 0.9359 - val_bin_class_out_accuracy: 0.9932
# Epoch 3/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.1913 - segnet_out_loss: 0.1702 - bin_class_out_loss: 0.0210 - segnet_out_accuracy: 0.9415 - bin_class_out_accuracy: 0.9966 - val_loss: 0.1891 - val_segnet_out_loss: 0.1570 - val_bin_class_out_loss: 0.0321 - val_segnet_out_accuracy: 0.9428 - val_bin_class_out_accuracy: 0.9955
# Epoch 4/10
# 221/221 [==============================] - 75s 341ms/step - loss: 0.1559 - segnet_out_loss: 0.1434 - bin_class_out_loss: 0.0125 - segnet_out_accuracy: 0.9499 - bin_class_out_accuracy: 0.9966 - val_loss: 0.1671 - val_segnet_out_loss: 0.1458 - val_bin_class_out_loss: 0.0213 - val_segnet_out_accuracy: 0.9458 - val_bin_class_out_accuracy: 0.9932
# Epoch 5/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.1331 - segnet_out_loss: 0.1246 - bin_class_out_loss: 0.0086 - segnet_out_accuracy: 0.9560 - bin_class_out_accuracy: 0.9977 - val_loss: 0.1613 - val_segnet_out_loss: 0.1400 - val_bin_class_out_loss: 0.0213 - val_segnet_out_accuracy: 0.9477 - val_bin_class_out_accuracy: 0.9909
# Epoch 6/10
# 221/221 [==============================] - 75s 340ms/step - loss: 0.1228 - segnet_out_loss: 0.1132 - bin_class_out_loss: 0.0097 - segnet_out_accuracy: 0.9594 - bin_class_out_accuracy: 0.9977 - val_loss: 0.1545 - val_segnet_out_loss: 0.1363 - val_bin_class_out_loss: 0.0183 - val_segnet_out_accuracy: 0.9497 - val_bin_class_out_accuracy: 0.9955
# Epoch 7/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.1102 - segnet_out_loss: 0.1037 - bin_class_out_loss: 0.0065 - segnet_out_accuracy: 0.9625 - bin_class_out_accuracy: 0.9989 - val_loss: 0.1594 - val_segnet_out_loss: 0.1364 - val_bin_class_out_loss: 0.0230 - val_segnet_out_accuracy: 0.9493 - val_bin_class_out_accuracy: 0.9864
# Epoch 8/10
# 221/221 [==============================] - 75s 339ms/step - loss: 0.0990 - segnet_out_loss: 0.0958 - bin_class_out_loss: 0.0031 - segnet_out_accuracy: 0.9653 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1575 - val_segnet_out_loss: 0.1376 - val_bin_class_out_loss: 0.0199 - val_segnet_out_accuracy: 0.9502 - val_bin_class_out_accuracy: 0.9886
# Epoch 9/10
# 221/221 [==============================] - 74s 337ms/step - loss: 0.0913 - segnet_out_loss: 0.0897 - bin_class_out_loss: 0.0016 - segnet_out_accuracy: 0.9676 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1529 - val_segnet_out_loss: 0.1371 - val_bin_class_out_loss: 0.0158 - val_segnet_out_accuracy: 0.9510 - val_bin_class_out_accuracy: 0.9909
# Epoch 10/10
# 221/221 [==============================] - 74s 336ms/step - loss: 0.0842 - segnet_out_loss: 0.0834 - bin_class_out_loss: 8.6752e-04 - segnet_out_accuracy: 0.9699 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1547 - val_segnet_out_loss: 0.1387 - val_bin_class_out_loss: 0.0161 - val_segnet_out_accuracy: 0.9503 - val_bin_class_out_accuracy: 0.9955
# -------------------- start cross val 4/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 85s 357ms/step - loss: 0.6947 - segnet_out_loss: 0.4783 - bin_class_out_loss: 0.2163 - segnet_out_accuracy: 0.7661 - bin_class_out_accuracy: 0.9253 - val_loss: 0.2963 - val_segnet_out_loss: 0.2630 - val_bin_class_out_loss: 0.0333 - val_segnet_out_accuracy: 0.9024 - val_bin_class_out_accuracy: 0.9932
# Epoch 2/10
# 221/221 [==============================] - 76s 345ms/step - loss: 0.2733 - segnet_out_loss: 0.2355 - bin_class_out_loss: 0.0377 - segnet_out_accuracy: 0.9175 - bin_class_out_accuracy: 0.9926 - val_loss: 0.2014 - val_segnet_out_loss: 0.1784 - val_bin_class_out_loss: 0.0230 - val_segnet_out_accuracy: 0.9386 - val_bin_class_out_accuracy: 0.9955
# Epoch 3/10
# 221/221 [==============================] - 75s 341ms/step - loss: 0.1904 - segnet_out_loss: 0.1782 - bin_class_out_loss: 0.0122 - segnet_out_accuracy: 0.9398 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1722 - val_segnet_out_loss: 0.1500 - val_bin_class_out_loss: 0.0222 - val_segnet_out_accuracy: 0.9474 - val_bin_class_out_accuracy: 0.9909
# Epoch 4/10
# 221/221 [==============================] - 76s 344ms/step - loss: 0.1586 - segnet_out_loss: 0.1489 - bin_class_out_loss: 0.0097 - segnet_out_accuracy: 0.9487 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1625 - val_segnet_out_loss: 0.1376 - val_bin_class_out_loss: 0.0249 - val_segnet_out_accuracy: 0.9511 - val_bin_class_out_accuracy: 0.9909
# Epoch 5/10
# 221/221 [==============================] - 75s 342ms/step - loss: 0.1386 - segnet_out_loss: 0.1286 - bin_class_out_loss: 0.0100 - segnet_out_accuracy: 0.9551 - bin_class_out_accuracy: 0.9966 - val_loss: 0.1480 - val_segnet_out_loss: 0.1320 - val_bin_class_out_loss: 0.0161 - val_segnet_out_accuracy: 0.9516 - val_bin_class_out_accuracy: 0.9955
# Epoch 6/10
# 221/221 [==============================] - 77s 351ms/step - loss: 0.1231 - segnet_out_loss: 0.1157 - bin_class_out_loss: 0.0074 - segnet_out_accuracy: 0.9590 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1602 - val_segnet_out_loss: 0.1267 - val_bin_class_out_loss: 0.0335 - val_segnet_out_accuracy: 0.9544 - val_bin_class_out_accuracy: 0.9841
# Epoch 7/10
# 221/221 [==============================] - 75s 342ms/step - loss: 0.1139 - segnet_out_loss: 0.1068 - bin_class_out_loss: 0.0070 - segnet_out_accuracy: 0.9619 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1364 - val_segnet_out_loss: 0.1245 - val_bin_class_out_loss: 0.0120 - val_segnet_out_accuracy: 0.9539 - val_bin_class_out_accuracy: 0.9977
# Epoch 8/10
# 221/221 [==============================] - 75s 342ms/step - loss: 0.1010 - segnet_out_loss: 0.0983 - bin_class_out_loss: 0.0026 - segnet_out_accuracy: 0.9647 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1419 - val_segnet_out_loss: 0.1246 - val_bin_class_out_loss: 0.0173 - val_segnet_out_accuracy: 0.9560 - val_bin_class_out_accuracy: 0.9932
# Epoch 9/10
# 221/221 [==============================] - 76s 343ms/step - loss: 0.0982 - segnet_out_loss: 0.0920 - bin_class_out_loss: 0.0062 - segnet_out_accuracy: 0.9670 - bin_class_out_accuracy: 0.9989 - val_loss: 0.1407 - val_segnet_out_loss: 0.1240 - val_bin_class_out_loss: 0.0167 - val_segnet_out_accuracy: 0.9553 - val_bin_class_out_accuracy: 0.9932
# Epoch 10/10
# 221/221 [==============================] - 76s 343ms/step - loss: 0.0889 - segnet_out_loss: 0.0860 - bin_class_out_loss: 0.0029 - segnet_out_accuracy: 0.9692 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1481 - val_segnet_out_loss: 0.1252 - val_bin_class_out_loss: 0.0229 - val_segnet_out_accuracy: 0.9552 - val_bin_class_out_accuracy: 0.9909
# -------------------- start cross val 5/5 --------------------
# Epoch 1/10
# 221/221 [==============================] - 87s 367ms/step - loss: 0.6971 - segnet_out_loss: 0.4805 - bin_class_out_loss: 0.2166 - segnet_out_accuracy: 0.7828 - bin_class_out_accuracy: 0.9202 - val_loss: 0.2869 - val_segnet_out_loss: 0.2543 - val_bin_class_out_loss: 0.0326 - val_segnet_out_accuracy: 0.9135 - val_bin_class_out_accuracy: 0.9932
# Epoch 2/10
# 221/221 [==============================] - 79s 360ms/step - loss: 0.2697 - segnet_out_loss: 0.2318 - bin_class_out_loss: 0.0379 - segnet_out_accuracy: 0.9197 - bin_class_out_accuracy: 0.9904 - val_loss: 0.1948 - val_segnet_out_loss: 0.1834 - val_bin_class_out_loss: 0.0113 - val_segnet_out_accuracy: 0.9345 - val_bin_class_out_accuracy: 0.9955
# Epoch 3/10
# 221/221 [==============================] - 79s 360ms/step - loss: 0.1927 - segnet_out_loss: 0.1752 - bin_class_out_loss: 0.0175 - segnet_out_accuracy: 0.9402 - bin_class_out_accuracy: 0.9955 - val_loss: 0.1720 - val_segnet_out_loss: 0.1561 - val_bin_class_out_loss: 0.0159 - val_segnet_out_accuracy: 0.9440 - val_bin_class_out_accuracy: 0.9955
# Epoch 4/10
# 221/221 [==============================] - 80s 365ms/step - loss: 0.1625 - segnet_out_loss: 0.1475 - bin_class_out_loss: 0.0150 - segnet_out_accuracy: 0.9488 - bin_class_out_accuracy: 0.9977 - val_loss: 0.1547 - val_segnet_out_loss: 0.1449 - val_bin_class_out_loss: 0.0099 - val_segnet_out_accuracy: 0.9470 - val_bin_class_out_accuracy: 0.9977
# Epoch 5/10
# 221/221 [==============================] - 80s 365ms/step - loss: 0.1387 - segnet_out_loss: 0.1282 - bin_class_out_loss: 0.0105 - segnet_out_accuracy: 0.9549 - bin_class_out_accuracy: 0.9972 - val_loss: 0.1492 - val_segnet_out_loss: 0.1389 - val_bin_class_out_loss: 0.0103 - val_segnet_out_accuracy: 0.9476 - val_bin_class_out_accuracy: 0.9977
# Epoch 6/10
# 221/221 [==============================] - 80s 361ms/step - loss: 0.1219 - segnet_out_loss: 0.1143 - bin_class_out_loss: 0.0076 - segnet_out_accuracy: 0.9595 - bin_class_out_accuracy: 0.9983 - val_loss: 0.1417 - val_segnet_out_loss: 0.1359 - val_bin_class_out_loss: 0.0059 - val_segnet_out_accuracy: 0.9492 - val_bin_class_out_accuracy: 1.0000
# Epoch 7/10
# 221/221 [==============================] - 79s 358ms/step - loss: 0.1088 - segnet_out_loss: 0.1052 - bin_class_out_loss: 0.0036 - segnet_out_accuracy: 0.9624 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1387 - val_segnet_out_loss: 0.1348 - val_bin_class_out_loss: 0.0040 - val_segnet_out_accuracy: 0.9497 - val_bin_class_out_accuracy: 1.0000
# Epoch 8/10
# 221/221 [==============================] - 79s 357ms/step - loss: 0.0995 - segnet_out_loss: 0.0970 - bin_class_out_loss: 0.0026 - segnet_out_accuracy: 0.9653 - bin_class_out_accuracy: 0.9994 - val_loss: 0.1395 - val_segnet_out_loss: 0.1336 - val_bin_class_out_loss: 0.0059 - val_segnet_out_accuracy: 0.9513 - val_bin_class_out_accuracy: 1.0000
# Epoch 9/10
# 221/221 [==============================] - 79s 357ms/step - loss: 0.0910 - segnet_out_loss: 0.0896 - bin_class_out_loss: 0.0014 - segnet_out_accuracy: 0.9681 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1382 - val_segnet_out_loss: 0.1338 - val_bin_class_out_loss: 0.0044 - val_segnet_out_accuracy: 0.9507 - val_bin_class_out_accuracy: 1.0000
# Epoch 10/10
# 221/221 [==============================] - 79s 358ms/step - loss: 0.0848 - segnet_out_loss: 0.0837 - bin_class_out_loss: 0.0011 - segnet_out_accuracy: 0.9703 - bin_class_out_accuracy: 1.0000 - val_loss: 0.1367 - val_segnet_out_loss: 0.1327 - val_bin_class_out_loss: 0.0040 - val_segnet_out_accuracy: 0.9526 - val_bin_class_out_accuracy: 1.0000

# %%
# extract the wanted metrics
result = []
for i in range(CVfolds):
    result.append([cv_history[i]['segnet_out_accuracy'],
                    cv_history[i]['val_segnet_out_accuracy']])

# %%
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(CVfolds):
    ax.plot(result[i][0], linestyle=":", label = f"segment acc, cv {i}")
for i in range(CVfolds):
    ax.plot(result[i][1], linestyle="-", label = f"val segment acc, cv {i}")
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('MTL with segmentation and binary')
plt.legend()
plt.ylim([0.75, 1])
plt.grid()
plt.show()

# %%
# Print out the results to see offline
print("set \tsegmen ")
for i in range(CVfolds):
    print(f"CV {i+1} \t{np.round(result[i][1][-1], 4)}")

print("-----------------------------")
avg = np.round(np.mean(result, axis=0), 4)
std = np.round(np.std(result, axis=0), 4)
print(f"Avg  \t{avg[1][-1]} ")
print(f"Std  \t{std[1][-1]} ")
# Out:
# set 	segmen
# CV 1 	0.9538
# CV 2 	0.9559
# CV 3 	0.9503
# CV 4 	0.9552
# CV 5 	0.9526
# -----------------------------
# Avg  	0.9536
# Std  	0.002
